# %% [markdown]
# **Топологическая оптимизация** – это оптимизация распределения материала в проектной области при воздействии на нее заданных нагрузок и использовании ограничений различного рода: геометрических, прочностных, жесткостных и др.
#
#
# Снижение массы и увеличение удельной прочности конструкций – важнейшие задачи, стоящие сегодня перед конструкторами всего мира. Решение данных проблем напрямую связано с задачей поиска оптимальных геометрических параметров проектируемого изделия.
#
# Целью ТО является определение оптимального распределения материала в области проектирования при заданных нагрузках с удовлетворением критериев оптимизации, иначе говоря, определение лучшего использования материала для исследуемого объекта или конструкции, так, чтобы целевая функция параметра имела максимальное или минимальное значение
# при наличии существующих ограничений. В отличие от традиционной оптимизации топологическая оптимизация не требует указания параметров оптимизации (т.е. независимых переменных, подвергаемых оптимизации) в явном виде. В топологической оптимизации параметром оптимизации является функция распределения материала по объему конструкции. Таким образом, основной особенностью задач оптимизации размеров является то, что область проектирования известна заранее, и она фиксирована в процессе оптимизации, а переменной проектирования является сама форма.

# %% [markdown]
# <math>\begin{align}
# &\underset{x}{\operatorname{minimize}} & &F = F(\mathbf{u(\rho), \rho}) =  \int_{\Omega}  f(\mathbf{u(\rho), \rho}) \mathrm{d}V \\
# &\operatorname{subject\;to}
# & &G_0(\rho) = \int_{\Omega} \rho \mathrm{d}V - V_0 \leq 0 \\
# &&&G_j(\mathbf{u}(\rho), \rho) \leq 0 \text{ with } j = 1, ..., m
# \end{align}</math>

# %% [markdown]
# Постановка задачи топологической оптимизации включает в себя следующее:
#
# * Целевая функция $ F(\mathbf{u(\rho), \rho})$. Наиболее распространенной целевой функцией является минимизация податливости конструкции через минимизацию энергии деформации.
# * Параметр проектирования - вектор псевдоплотности, показывает наличие или отсутствие материала в элементе $ \rho(\mathbf{u}) $. Материал либо присутствует, обозначен $1$, либо отсутствует, обозначен $0$. $ \mathbf{u} $ - это поле состояния, которое удовлетворяет линейному или нелинейному уравнению состояния.
# * Пространство проектирования $ (\Omega)$. Указывает на допустимый объем, в котором может существовать конструкция. При определении пространства проектирования области или компоненты в модели, которые не могут быть изменены в ходе оптимизации, рассматриваются как области без проекта.
# * $ m $ ограничение $ G_j(\mathbf{u}(\rho), \rho) \leq 0 $ область, в которой существует решение. Примерами являются максимальное количество материала(ограничение объема) или максимальные значения напряжения.
#
# Оценка $ \mathbf{u(\rho)} $ часто включает в себя решение дифференциального уравнения. Чаще всего это делается с помощью метода конечных элементов, поскольку эти уравнения не имеют известного аналитического решения.

# %% [markdown]
# В настоящее время известны следующие основные методы ТО: **SIMP** (твердый изотропный материал с пенализацией), **ESO** (эволюционная структурная оптимизация) и **Level-Set** (метод установления уровня) и их различные комбинации.

# %% [markdown]
# **Метод ESO** основан на определении уровня напряжений в произвольной части конструкции методом конечных элементов. Индикатором неэффективного использования материала является низкий уровень напряжений (или деформаций) в той или иной части конструкции.
# В идеале уровень напряжений в конструкции должен быть одинаковым, близким к предельному, но безопасному значению.
# Из этой концепции следует принцип удаления материала, согласно которому недостаточно нагруженный материал может быть удален, что приводит к удалению отдельных элементов конечно-элементной модели.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **SIMP-метод (Solid Isotropic Material with Penalization)**, или метод пенализации для твердого изотропного тела, – это метод ТО, основополагающая идея которого заключается в создании поля виртуальной плотности, представляющей аналог некоторой реальной характеристики объекта. Назначение метода состоит в уменьшении податливости конструкции вследствие перераспределения материала в рассматриваемой области пространства при известных граничных условиях. Результатом его использования является получение равнопрочного объекта в рамках рассматриваемой задачи. Широкое применение SIMP получил в аддитивных технологиях (технологиях 3D-печати), способных создавать объекты необходимой формы.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Основная идея метода **Level-Set** (установления уровня или множества уровней) состоит в том, чтобы выразить кривую или поверхность в неявном виде. При этом они принимаются в качестве установленного нулевого уровня многомерной функции. Затем прослеживается их деформация с помощью этой функции.
# Например, в оптимизации топологии структуры кривые или поверхности, изображающие ее границы, деформируются, чтобы минимизировать энергию упругой деформации.

# %% [markdown]
# **Целью данной работы** является применение глубокого обучения к решению наиболее трудоёмкой части традиционных методов оптимизации топологии, что позволит ускорение процесса оптимизации, достигнуть отличных обобщающих способностей при  абсолютной масштабируемости данной методики.
#
# Для достижения поставленной цели необходимо решить ряд задач:
# - сформировать датасет с использованием методики топологической оптимизации(на данном этапе не принципиально важно какой метод будет использован);
# - отобрать структуру сети для глубокого обучения;
# - подобрать параметры выбранной конфигурации сети и обучить её;
# - провести проверку полученной модели.

# %% [markdown]
# ## Формирование датасета
# Т.к. представленные методики топологической оптимизации работают как итеративные процессы, постараемся сформировать датасет, содержащий 50 итераций для каждой случайной задачи. Затем при обучении будем использовать первых 3-5 итерации и предсказывать структуру конструкции на 50.
#
# В качестве задачи для проверки гипотезы выберем нагружение плоской квадратной пластины, один край которой жестко закреплён, к другому приложена нагрузка (1 Н). При этом нагрузка будет перемещаться для формирования обучающего набора данных. Расчёт возникающих напряжений в конструкции проведем методом конечных элементов, при этом пластинку разобъём 1024 элемента(32х32).
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Для проведения анализа был создан файл библиотеки *libtopology*, загрузив которую и используя представленный ниже цикл, сформирован датасет содержащий тренировочные данные и целевую топологию(50я итерация).
#
# ```python
# import libtopology as tp
# X_ds = []
# Y_ds = []
# for i in range(2, 34, 2):
#     nelx  = 32 # общее количество элементов по горизонтали
#     nely = 32 # общее количество элементов в вертикальном направлении
#     volfrac = 0.5 # доля объема, которая определяет соотношение конечного объема и объема расчетной области.
#     penal = 3 # величина пенализации(штрафования)
#     rmin = 1.5 # радиус фильтра, обычно 3 (или размер нескольких элементов)
#     iterat = 50
#     crdX = i
#     for n in range(16, 67):
#         crdY = n
#         X, Y = tp.top(nelx, nely, volfrac, penal, rmin, crdX, crdY, iterat)
#         X_ds.append(X)
#         Y_ds.append(Y)
# np.savez('X', np.array(X_ds), np.array(Y_ds))```
#
# В библиотеке *libtopology* проводится топологическая: на каждом шаге строится геометрия, проводится решение задачи методом конечных элементов, формируется матрица плотностей, которые сравниваются с критерием оптимальности, затем конструкция обновляется.

# %% [markdown]
# Загрузим сформированнны датасет и определим тренировочные данные и целевую конструкцию

# %%
import time
from time import time
import random
import pylab as py
import numpy as np
import matplotlib.pyplot as plt
from scipy.sparse import lil_matrix
from skimage.transform import resize
# Out:
# C:\Users\Shakhrai\Anaconda3\envs\mitjasha\lib\site-packages\dask\config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}

# %%
#!tensorboard --logdir=logs

# %%
data = np.load('./X.npz')
data.files
# Out:
# ['arr_0', 'arr_1']

# %%
train = data['arr_0']
target = data['arr_1']
print(train.shape, target.shape)

plt.figure(figsize=(10, 8))
plt.subplot(1,3,1)
plt.title('3 итерация')
py.imshow(train[8][2,:,:], cmap = py.cm.gray)

plt.subplot(1,3,2)
plt.title('5 итерация')
py.imshow(train[8][4,:,:], cmap = py.cm.gray)

plt.subplot(1,3,3)
plt.title('50 итерация')
py.imshow(target[8][0,:,:], cmap = py.cm.gray)
py.show()
# Out:
# (816, 50, 32, 32) (816, 1, 32, 32)

# %%
# для дальнейшей работы поменяем местами оси 1 и 3
train = train.swapaxes(1,3)
target = target.swapaxes(1,3)
target.shape, train.shape
# Out:
# ((816, 32, 32, 1), (816, 32, 32, 50))

# %% [markdown]
# Также вручную проведём аугменатацию данных - повороты на 90, 180, 270 градусов. Применить случайную аугментацию поворотами не предатавляется возможным, ввиду того, что при направлении сил не под прямым углом топология может значительно измениться. Для решения таких задач необходимо скорректировать исходный датасет и предусмотреть там решение такого рода задач.

# %%
train_res90 = np.rot90(train, 1, (1,2))
target90 = np.rot90(target, 1, (1,2))
train_res180 = np.rot90(train, 2)
target180 = np.rot90(target, 2)
train_res270 = np.rot90(train, 3, (1,2))
target270 = np.rot90(target, 3, (1,2))

train_fin = np.vstack((train, train_res90))
train_fin = np.vstack((train_fin, train_res180))
train_fin = np.vstack((train_fin, train_res270))

target_fin = np.vstack((target, target90))
target_fin = np.vstack((target_fin, target180))
target_fin = np.vstack((target_fin, target270))

train_fin.shape, target_fin.shape
# Out:
# ((3264, 32, 32, 50), (3264, 32, 32, 1))

# %% [markdown]
# Для тренировки будем использовать несколько подходов:
#     1. обучать модель на 5 итерации
#     2. обучать модель на 2-5 итерации
#     3. обучать модель на разнице между 5 и 4 итерацией
#     4. комбинация подходов

# %%
train_5 = (train_fin[:,:,:,4]/(train_fin[:,:,:,4]).max()).reshape(3264,32,32,1)
train_2_5 = train_fin[:,:,:,1:4]/(train_fin[:,:,:,1:4]).max()
train_res = (abs(train_fin[:,:,:,4] - train_fin[:,:,:,3])/(abs(train_fin[:,:,:,4] - train_fin[:,:,:,3])).max()).reshape(3264,32,32,1)
target_fin = target_fin/target_fin.max()

# %% [markdown]
# Определим порог для создания маски с результатом оптимизации на последнем шаге. При обучении попробуем предсказывать как результат на последнем шаге так и маску.

# %%
thresh1 = target_fin.copy()
thresh1[thresh1 > target_fin.mean()*1.5] = 1
thresh1[thresh1 <= target_fin.mean()*1.5] = 0
py.imshow(np.squeeze(thresh1[1]))
plt.show()

# %% [markdown]
# Отобразим обучающие данные для первых трёх подходов к обучению, а так же целевую топологию конструкции

# %%
ix = random.randint(0, len(target_fin)-1)
print(ix)

plt.figure(figsize=(16, 12))
plt.subplot(1,4,1)
plt.title('5 итерация')
py.imshow(np.squeeze(train_5[ix]))

plt.subplot(1,4,2)
plt.title('итерации 2-5')
py.imshow(np.squeeze(train_2_5[ix]))

plt.subplot(1,4,3)
plt.title('разница итераций 5 и 4')
py.imshow(np.squeeze(train_res[ix]))

plt.subplot(1,4,4)
plt.title('50 итерация')
py.imshow(np.squeeze(thresh1[ix]), cmap='pink')
py.imshow(np.squeeze(target_fin[ix]), alpha=0.5)
plt.show()
# Out:
# 3127

# %% [markdown]
# Т.к. имеется две задачи, одна - предсказание маски(сегментация изображения), а вторая предсказание топологии в виде набора плотностей(как в исходном датасете), то будем использовать две разные метрики для задач
#
# Для задачи сегментации бцдем использовать метрику Intersection over Union(IoU) или коэффициент Жаккара и её модификацию в виде среднего значения:
# <math>\begin{align} K_{1,-1} = \frac{n(A \cap B)}{n(A) + n(B) - n(A \cap B)} = \frac{n(A \cap B)}{ n(A \cup B)}  \end{align}</math>
#
# Для задачи предсказания топологии в виде набора плотностей будет использована средняя квадратическая ошибка(Mean squared error)
# <math>\begin{align}{MSE}=\frac{1}{n}\sum_{i=1}^n(Y_i-\hat{Y_i})^2 \end{align}</math>
#
# # !!!! Также хочу попробовать :
# Коэффициент детерминации
# $R^2 =1-\frac {\hat{\sigma}^2}{\hat{\sigma}^2_y}=1-\frac {SS_{res}/n}{SS_{tot}/n}=1-\frac {SS_{res}} {SS_{tot}}$
#
# Коэффициент взаимной корреляции цифровых изображений(digital image correlation)
# $r_{ij}(u,v,\frac{\partial u}{\partial x},\frac{\partial u}{\partial y},\frac{\partial v}{\partial x},\frac{\partial v}{\partial y}) = 1 - \frac{\sum_i \sum_j [F(x_i,y_j)-\bar{F}][G(x_i ^{\star} ,y_j ^{\star})-\bar{G}]}{\sqrt{\sum_i \sum_j {[F(x_i,y_j)-\bar{F}]^2} \sum_i \sum_j {[G(x_i ^{\star},y_j ^{\star})-\bar{G}]^2}}}$

# %%
# это IoU метрика 
def iou(y_true, y_pred):
    smooth = 1e-12
    intersection = K.sum(y_true * y_pred, axis=[0, -1, -2])
    sum_ = K.sum(y_true + y_pred, axis=[0, -1, -2])
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return K.mean(jac)

# это IoU метрика (среднее значение)
def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0, 1, 0.1):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

def r2(y_true, y_pred):
    numerator = K.sum(y_true - y_pred, axis=[0, -1, -2])
    denominator = K.sum(y_true + K.mean(y_true), axis=[0, -1, -2])
    r2 = 1 - (numerator**2 / denominator**2)
    return K.mean(r2)

def dic(y_true, y_pred):
    numerator = K.sum(y_true - K.mean(y_true), axis=[0, -1, -2])*K.sum(y_pred - K.mean(y_pred), axis=[0, -1, -2])
    denominator = K.sum(y_true - K.mean(y_true), axis=[0, -1, -2])**2 * K.sum(y_pred - K.mean(y_pred), axis=[0, -1, -2])**2
    dic = 1 - (numerator / denominator**0.5)
    return K.mean(dic)

def mse(y_true, y_pred):
    mse = tf.keras.metrics.mean_squared_error(y_true, y_pred)
    return K.mean(mse)

# %% [markdown]
# Для решения поставленной задачи будем использовать сеть типа U-net, которая в последнее время пользуется большой популярностью для решения задач сегментации изображений.
#
# **U-Net** — это свёрточная нейронная сеть, которая была создана в 2015 году для сегментации биомедицинских изображений в отделении Computer Science Фрайбургского университета
# <ref>Статья авторов U-Net: https://arxiv.org/pdf/1505.04597.pdf U-Net: Convolutional Networks for Biomedical Image Segmentation]</ref>.
# Архитектура сети представляет собой полносвязную свёрточную сеть, модифицированную так, чтобы она могла работать с меньшим количеством примеров (обучающих образов) и делала более точную сегментацию.
#
# Сеть содержит сжимающий путь (слева) и расширяющий путь (справа), поэтому архитектура похожа на букву U, что и отражено в названии. На каждом шаге мы удваиваем количество каналов признаков.
#
# Сжимающий путь похож на типичную свёрточную сеть, он содержит два подряд свёрточных слоя 3x3, после которых идет слой ReLU и пулинг с функцией максимума 2×2 с шагом 2.
#
# Каждый шаг расширяющего пути содержит слой, обратный пулингу, который расширяет карту признаков, после которого следует свертка 2x2, которая уменьшает количество каналов признаков. После идет конкатенация с соответствующем образом обрезанной картой признаков из сжимающего пути и две свертки 3x3, после каждой из которой идет ReLU. Обрезка нужна из-за того, что мы теряем пограничные пиксели в каждой свертке. На последнем слое свертка 1x1 используется для приведения каждого 64-компонентного вектора признаков до требуемого количества классов.
#
# ![graph_large_attrs_key=_too_large_attrs&limit_attr_size=1024&run=1557493013.png](attachment:graph_large_attrs_key=_too_large_attrs&limit_attr_size=1024&run=1557493013.png)

# %%
# импортируем необходимые бибилиотеки
import keras
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, load_model, Model
from keras.layers import Dense, Dropout, Flatten, BatchNormalization, Input, Lambda, normalization
from keras.layers import Conv2D, MaxPooling2D, Conv2DTranspose, concatenate, UpSampling2D
from keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
from keras.optimizers import Adam
from keras.utils import np_utils

import tensorflow as tf

from sklearn.model_selection import train_test_split

from segmentation_models.losses import bce_jaccard_loss
from segmentation_models.metrics import iou_score
# Out:
# Using TensorFlow backend.
# C:\Users\Shakhrai\Anaconda3\envs\mitjasha\lib\site-packages\classification_models\resnext\__init__.py:4: UserWarning: Current ResNext models are deprecated, use keras.applications ResNeXt models
#   warnings.warn('Current ResNext models are deprecated, '

# %%
train_x, test_x, train_y, test_y = train_test_split(train_5, target_fin, test_size=1/8.2, random_state=3017)
train_x.shape, test_x.shape
# Out:
# ((2865, 32, 32, 1), (399, 32, 32, 1))

# %% [markdown]
# Функция для построения модели сети U-net

# %%
def u_net(z=1):
    inputs = Input((32, 32, z))
    #s = Lambda(lambda x: x / 255) (inputs)
    #norm = BatchNormalization() (s)
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (inputs)
    c1 = Dropout(0.2) (c1)
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c1)
    p1 = MaxPooling2D((2, 2)) (c1)

    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p1)
    c2 = Dropout(0.2) (c2)
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c2)
    p2 = MaxPooling2D((2, 2)) (c2)

    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p2)
    #c3 = Dropout(0.2) (c3)
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c3)
    p3 = MaxPooling2D((2, 2)) (c3)

    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p3)
    #c4 = Dropout(0.2) (c4)
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c4)
    p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p4)
    #c5 = Dropout(0.3) (c5)
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c5)

    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u6)
    #c6 = Dropout(0.2) (c6)
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c6)

    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u7)
    #c7 = Dropout(0.2) (c7)
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c7)

    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u8)
    c8 = Dropout(0.2) (c8)
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c8)

    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u9)
    c9 = Dropout(0.2) (c9)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c9)

    outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

    model = Model(inputs=[inputs], outputs=[outputs])
    model.compile(optimizer='adam', loss=bce_jaccard_loss, metrics=[iou_score, mean_iou, mse])
    model.summary()
    
    return model

# %% [markdown]
# Далее обучим 3 сети для определения конструкции на 50 шаге на основе плотностей.
# Первый подход - модель обучаем на тренировочных данных снятых на 5 итерации при топологической оптимизации

# %%
model1 = u_net()
tensorboard = TensorBoard(log_dir='logs/{}'.format(time()))
earlystopper = EarlyStopping(patience=5, verbose=1)
checkpointer = ModelCheckpoint('model1_segm.h5', verbose=1, save_best_only=True)
results = model1.fit(train_x, train_y, validation_split=0.1, batch_size=64, epochs=100, 
                    callbacks=[earlystopper, checkpointer, tensorboard])
# Out:
# WARNING:tensorflow:From C:\Users\Shakhrai\Anaconda3\envs\mitjasha\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\Shakhrai\Anaconda3\envs\mitjasha\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From <ipython-input-10-ddb4a486220c>:13: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# ...

# %%
print('Метрики на тестовых данных: ', model1.evaluate(test_x, test_y))

print(results.history.keys())
# вывод истории по метрике
plt.plot(results.history['mean_iou'])
plt.plot(results.history['val_mean_iou'])
plt.title('model1 mean_iou')
plt.ylabel('IoU')
plt.xlabel('epoch')
plt.legend(['mean_iou', 'val_mean_iou'], loc='upper left')
plt.show()

# вывод истории по коэффициенту Жаккара
plt.plot(results.history['iou_score'])
plt.plot(results.history['val_iou_score'])
plt.title('model1 iou_score')
plt.ylabel('iou_score')
plt.xlabel('epoch')
plt.legend(['iou_score', 'val_iou_score'], loc='upper left')
plt.show()

# вывод истории по средней квадратичной ошибке
plt.plot(results.history['mse'])
plt.plot(results.history['val_mse'])
plt.title('model1 mse')
plt.ylabel('mse')
plt.xlabel('epoch')
plt.legend(['mse', 'val_mse'], loc='upper left')
plt.show()

# вывод истории по потерям
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('model1 loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()
# Out:
# 399/399 [==============================] - 1s 1ms/step
# Метрики на тестовых данных:  [0.859678876579256, 0.26121285019960616, 0.4280653684808497, 0.010375078865572027]
# dict_keys(['val_loss', 'val_iou_score', 'val_mean_iou', 'val_mse', 'loss', 'iou_score', 'mean_iou', 'mse'])

# %%
# Предсказания на тренировочных, валидационных и тестовых данных
#model1 = load_model('model1_segm.h5', custom_objects={'mean_iou': mean_iou, 'iou': iou})
preds_test = model1.predict(test_x, verbose=1)

# # Определение порога прогноза
# preds_test_t = (preds_test > 1).astype(np.uint8)

# Проверка работоспособности на случайном обучающем примере
ix = random.randint(0, len(preds_test)-1)
print(ix)
py.imshow(np.squeeze(test_y[ix]))
plt.show()
py.imshow(np.squeeze(preds_test[ix]))
plt.show()
# Out:
# 399/399 [==============================] - 0s 574us/step
# 298

# %% [markdown]
# Второй подход - обучать модель на 2-5 итерациях

# %%
train_x, test_x, train_y, test_y = train_test_split(train_2_5, target_fin, test_size=1/8.2, random_state=3017)

model2 = u_net(z=3)
 
tensorboard = TensorBoard(log_dir='logs/{}'.format(time()))
earlystopper = EarlyStopping(patience=5, verbose=1)
checkpointer = ModelCheckpoint('model2_segm.h5', verbose=1, save_best_only=True)
results = model2.fit(train_x, train_y, validation_split=0.1, batch_size=64, epochs=100, 
                    callbacks=[earlystopper, checkpointer, tensorboard])
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 32, 32, 16)   448         input_2[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 32, 32, 16)   0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 32, 32, 16)   2320        dropout_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 16, 16, 16)   0           conv2d_21[0][0]
# ...

# %%
print('Метрики на тестовых данных', model2.evaluate(test_x, test_y))

print(results.history.keys())
# вывод истории по метрике
plt.plot(results.history['mean_iou'])
plt.plot(results.history['val_mean_iou'])
plt.title('model2 mean_iou')
plt.ylabel('IoU')
plt.xlabel('epoch')
plt.legend(['mean_iou', 'val_mean_iou'], loc='upper left')
plt.show()

# вывод истории по коэффициенту Жаккара
plt.plot(results.history['iou_score'])
plt.plot(results.history['val_iou_score'])
plt.title('model2 iou_score')
plt.ylabel('iou_score')
plt.xlabel('epoch')
plt.legend(['iou_score', 'val_iou_score'], loc='upper left')
plt.show()

# вывод истории по средней квадратичной ошибке
plt.plot(results.history['mse'])
plt.plot(results.history['val_mse'])
plt.title('model2 mse')
plt.ylabel('mse')
plt.xlabel('epoch')
plt.legend(['mse', 'val_mse'], loc='upper left')
plt.show()

# вывод истории по потерям
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('model2 loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()
# Out:
# 399/399 [==============================] - 0s 747us/step
# Метрики на тестовых данных [0.8585647665767144, 0.26261985944327254, 0.4216946218545574, 0.01006710192510732]
# dict_keys(['val_loss', 'val_iou_score', 'val_mean_iou', 'val_mse', 'loss', 'iou_score', 'mean_iou', 'mse'])

# %%
# Предсказания на тестовых данных
#model1 = load_model('model2_segm.h5', custom_objects={'mean_iou': mean_iou, 'iou': iou})
preds_test = model2.predict(test_x, verbose=1)

# # Определение порога прогноза
# preds_test_t = (preds_test > 1).astype(np.uint8)

# Проверка работоспособности на случайном обучающем примере
ix = random.randint(0, len(preds_test)-1)
print(ix)
py.imshow(np.squeeze(test_y[ix]))
plt.show()
py.imshow(np.squeeze(preds_test[ix]))
plt.show()
# Out:
# 399/399 [==============================] - 0s 800us/step
# 133

# %% [markdown]
# Третий подход - обучение на разнице между 5 и 4 итерацией

# %%
train_x, test_x, train_y, test_y = train_test_split(train_res, target_fin, test_size=1/8.2, random_state=3017)

model3 = u_net()
 
tensorboard = TensorBoard(log_dir='logs/{}'.format(time()))
earlystopper = EarlyStopping(patience=5, verbose=1)
checkpointer = ModelCheckpoint('model3_segm.h5', verbose=1, save_best_only=True)
results = model3.fit(train_x, train_y, validation_split=0.1, batch_size=64, epochs=100, 
                    callbacks=[earlystopper, checkpointer, tensorboard])
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            (None, 32, 32, 1)    0
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 32, 32, 16)   160         input_3[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 32, 32, 16)   0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 32, 32, 16)   2320        dropout_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 16, 16, 16)   0           conv2d_40[0][0]
# ...

# %%
print('Метрики на тестовых данных', model3.evaluate(test_x, test_y))

print(results.history.keys())
# вывод истории по метрике
plt.plot(results.history['mean_iou'])
plt.plot(results.history['val_mean_iou'])
plt.title('model3 mean_iou')
plt.ylabel('IoU')
plt.xlabel('epoch')
plt.legend(['mean_iou', 'val_mean_iou'], loc='upper left')
plt.show()

# вывод истории по коэффициенту Жаккара
plt.plot(results.history['iou_score'])
plt.plot(results.history['val_iou_score'])
plt.title('model3 iou_score')
plt.ylabel('iou_score')
plt.xlabel('epoch')
plt.legend(['iou_score', 'val_iou_score'], loc='upper left')
plt.show()

# вывод истории по средней квадратичной ошибке
plt.plot(results.history['mse'])
plt.plot(results.history['val_mse'])
plt.title('model3 mse')
plt.ylabel('mse')
plt.xlabel('epoch')
plt.legend(['mse', 'val_mse'], loc='upper left')
plt.show()

# вывод истории по потерям
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('model3 loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()
# Out:
# 399/399 [==============================] - 0s 742us/step
# Метрики на тестовых данных [0.8570913293009115, 0.26602910365675925, 0.42305170862298264, 0.01074805886328295]
# dict_keys(['val_loss', 'val_iou_score', 'val_mean_iou', 'val_mse', 'loss', 'iou_score', 'mean_iou', 'mse'])

# %%
# Предсказания на тестовых данных
#model1 = load_model('model3_segm.h5', custom_objects={'mean_iou': mean_iou, 'iou': iou})
preds_test = model3.predict(test_x, verbose=1)

# # Определение порога прогноза
# preds_test_t = (preds_test > 1).astype(np.uint8)

# Проверка работоспособности на случайном обучающем примере
ix = random.randint(0, len(preds_test)-1)
print(ix)
py.imshow(np.squeeze(test_y[ix]))
plt.show()
py.imshow(np.squeeze(preds_test[ix]))
plt.show()
# Out:
# 399/399 [==============================] - 0s 1ms/step
# 261

# %% [markdown]
# ### Сравнение трёх подходов к предсказанию целевой топологии в виде плотностей
#
# ![image.png](attachment:image.png)
#
# Как видно из графиков изменения средней квадратичной ошибки на валидационных данных по соотношению скорость/качество лучшим является подход с обучением на трёх слоях (красная кривая).

# %% [markdown]
# ### Сегментация изображения и предсказание маски

# %%
train_x, test_x, train_y, test_y = train_test_split(train_5, thresh1, test_size=1/8.2, random_state=3017)

model4 = u_net()
 
tensorboard = TensorBoard(log_dir='logs/{}'.format(time()))
earlystopper = EarlyStopping(patience=5, verbose=1)
checkpointer = ModelCheckpoint('model4_segm.h5', verbose=1, save_best_only=True)
results = model4.fit(train_x, train_y, validation_split=0.1, batch_size=64, epochs=100, 
                    callbacks=[earlystopper, checkpointer, tensorboard])
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_4 (InputLayer)            (None, 32, 32, 1)    0
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 32, 32, 16)   160         input_4[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 32, 32, 16)   0           conv2d_58[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 32, 32, 16)   2320        dropout_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 16, 16, 16)   0           conv2d_59[0][0]
# ...

# %%
print('Метрики на тестовых данных', model4.evaluate(test_x, test_y))

print(results.history.keys())
# вывод истории по метрике
plt.plot(results.history['mean_iou'])
plt.plot(results.history['val_mean_iou'])
plt.title('model4 mean_iou')
plt.ylabel('IoU')
plt.xlabel('epoch')
plt.legend(['mean_iou', 'val_mean_iou'], loc='upper left')
plt.show()

# вывод истории по коэффициенту Жаккара
plt.plot(results.history['iou_score'])
plt.plot(results.history['val_iou_score'])
plt.title('model4 iou_score')
plt.ylabel('iou_score')
plt.xlabel('epoch')
plt.legend(['iou_score', 'val_iou_score'], loc='upper left')
plt.show()

# вывод истории по средней квадратичной ошибке
plt.plot(results.history['mse'])
plt.plot(results.history['val_mse'])
plt.title('model4 mse')
plt.ylabel('mse')
plt.xlabel('epoch')
plt.legend(['mse', 'val_mse'], loc='upper left')
plt.show()

# вывод истории по потерям
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('model4 loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()
# Out:
# 399/399 [==============================] - 0s 827us/step
# Метрики на тестовых данных [0.14345743647195341, 0.9063908227703028, 0.8716577960733782, 0.012385397556618341]
# dict_keys(['val_loss', 'val_iou_score', 'val_mean_iou', 'val_mse', 'loss', 'iou_score', 'mean_iou', 'mse'])

# %%
# Предсказания на тренировочных, валидационных и тестовых данных
#model4 = load_model('model4_segm.h5', custom_objects={'mean_iou': mean_iou, 'iou': iou})
preds_test = model4.predict(test_x, verbose=1)

# # Определение порога прогноза
# preds_test_t = (preds_test > 1).astype(np.uint8)

# Проверка работоспособности на случайном обучающем примере
ix = random.randint(0, len(preds_test)-1)
print(ix)
py.imshow(np.squeeze(test_y[ix]))
plt.show()
py.imshow(np.squeeze(preds_test[ix]))
plt.show()
# Out:
# 399/399 [==============================] - 0s 251us/step
# 285

# %% [markdown]
# Визуализация фильтров сверточной нейронной сети

# %%
n=0
for layer in model4.layers:
    # выбор сверточных слоёв
    n+=1
    if 'conv' not in layer.name:
        continue
    filters, biases = layer.get_weights()
    print(n, layer.name, filters.shape)
# Out:
# 2 conv2d_58 (3, 3, 1, 16)
# 4 conv2d_59 (3, 3, 16, 16)
# 6 conv2d_60 (3, 3, 16, 32)
# 8 conv2d_61 (3, 3, 32, 32)
# 10 conv2d_62 (3, 3, 32, 64)
# 11 conv2d_63 (3, 3, 64, 64)
# 13 conv2d_64 (3, 3, 64, 128)
# 14 conv2d_65 (3, 3, 128, 128)
# 16 conv2d_66 (3, 3, 128, 256)
# 17 conv2d_67 (3, 3, 256, 256)
# 18 conv2d_transpose_13 (2, 2, 128, 256)
# 20 conv2d_68 (3, 3, 256, 128)
# 21 conv2d_69 (3, 3, 128, 128)
# 22 conv2d_transpose_14 (2, 2, 64, 128)
# 24 conv2d_70 (3, 3, 128, 64)
# 25 conv2d_71 (3, 3, 64, 64)
# 26 conv2d_transpose_15 (2, 2, 32, 64)
# 28 conv2d_72 (3, 3, 64, 32)
# 30 conv2d_73 (3, 3, 32, 32)
# 31 conv2d_transpose_16 (2, 2, 16, 32)
# 33 conv2d_74 (3, 3, 32, 16)
# 35 conv2d_75 (3, 3, 16, 16)
# 36 conv2d_76 (1, 1, 16, 1)

# %%
# получаем веса со свёрточного слоя
filters, biases = model4.layers[10].get_weights()

# %%
# нормальзация фильтров, для отображение значений от 0 до 1
f_min, f_max = filters.min(), filters.max()
filters = (filters - f_min) / (f_max - f_min)

# %%
# отображение нескольких первых фильтров для примера
n_filters, ix = 6, 1
for i in range(n_filters):
    # получаем фильтр
    f = filters[:, :, :, i]
    # отображение фильтров по сетке
    for j in range(3):
        ax = py.subplot(n_filters, 3, ix)
        ax.set_xticks([])
        ax.set_yticks([])
        # отображение в оттенках серого
        py.imshow(f[:, :, j], cmap='gray')
        ix += 1

py.show()

# %% [markdown]
# Далее получим изображения признаков по некоторым слоям, которые в процессе обучения получает сверточная нейронная сеть

# %%
# переопределяем модель для вывода сразу после первого скрытого слоя
ixs = [2, 4, 6, 8, 10, 16, 19, 21, 26, 30]
outputs = [model4.layers[i+1].output for i in ixs]
model_ = Model(inputs=model4.inputs, outputs=outputs)
model_.summary()

# определяем изображение для анализа
img = test_x[18]
img = np.expand_dims(img, axis=0)
feature_maps = model_.predict(img)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 32, 32, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 16)   160         input_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 16)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 16)   2320        dropout_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 16)   0           conv2d_2[0][0]
# ...

# %%
# выводим результаты для каждого указанного слоя
square = 4
for fmap in feature_maps:
    ix = 1
    for _ in range(square):
        for _ in range(square):
            ax = py.subplot(square, square, ix)
            ax.set_xticks([])
            ax.set_yticks([])
            py.imshow(fmap[0, :, :, ix-1], cmap='RdBu')
            py.title(ix)
            ix += 1
    py.show()

# %% [markdown]
# # Linknet
# **LinkNet** - это легкая глубокая архитектура нейронной сети, предназначенная для выполнения семантической сегментации.
#
#
# Начальный блок содержит слой свертки с размером фильтра 7x7 и шагом 2; за ним следует слой MaxPooling2D с размером окна 2x2 и шагом 2. Аналогично, последний блок выполняет полную свертку, принимая карты характеристик от 64 до 32, после чего следует двумерная свертка.
# В нашем случае отключены по два блока энкодела и декодера, т.к. разрешене рисунков маленькое.
#
# ![image.png](attachment:image.png)

# %%
from keras.layers import Input, concatenate, Conv2D, MaxPooling2D, Activation, UpSampling2D, BatchNormalization, add
from keras.layers.core import Flatten, Reshape
from keras.models import Model
from keras.regularizers import l2
import keras.backend as K

# %%
def _shortcut(input, residual):
    
    input_shape = K.int_shape(input)
    residual_shape = K.int_shape(residual)
    stride_width = int(round(input_shape[1] / residual_shape[1]))
    stride_height = int(round(input_shape[2] / residual_shape[2]))
    equal_channels = input_shape[3] == residual_shape[3]

    shortcut = input
    if stride_width > 1 or stride_height > 1 or not equal_channels:
        shortcut = Conv2D(filters=residual_shape[3],
                          kernel_size=(1, 1),
                          strides=(stride_width, stride_height),
                          padding="valid",
                          kernel_initializer="he_normal",
                          kernel_regularizer=l2(0.0001))(input)

    return add([shortcut, residual])

def encoder_block(input_tensor, m, n):
    x = BatchNormalization()(input_tensor)
    x = Activation('relu')(x)
    x = Conv2D(filters=n, kernel_size=(3, 3), strides=(2, 2), padding="same")(x)

    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(filters=n, kernel_size=(3, 3), padding="same")(x)

    added_1 = _shortcut(input_tensor, x)

    x = BatchNormalization()(added_1)
    x = Activation('relu')(x)
    x = Conv2D(filters=n, kernel_size=(3, 3), padding="same")(x)

    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(filters=n, kernel_size=(3, 3), padding="same")(x)

    added_2 = _shortcut(added_1, x)

    return added_2

def decoder_block(input_tensor, m, n):
    x = BatchNormalization()(input_tensor)
    x = Activation('relu')(x)
    x = Conv2D(filters=int(m/4), kernel_size=(1, 1))(x)

    x = UpSampling2D((2, 2))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(filters=int(m/4), kernel_size=(3, 3), padding='same')(x)

    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(filters=n, kernel_size=(1, 1))(x)

    return x

def LinkNet(input_shape=(32, 32, 1), classes=1):
    inputs = Input(shape=input_shape)

    x = BatchNormalization()(inputs)
    x = Activation('relu')(x)
    x = Conv2D(filters=64, kernel_size=(7, 7), strides=(2, 2))(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding="same")(x)

    encoder_1 = encoder_block(input_tensor=x, m=64, n=64)

    encoder_2 = encoder_block(input_tensor=encoder_1, m=64, n=128)

#     encoder_3 = encoder_block(input_tensor=encoder_2, m=128, n=256)

#     encoder_4 = encoder_block(input_tensor=encoder_3, m=256, n=512)

# #     decoder_4 = decoder_block(input_tensor=encoder_4, m=512, n=256)

# #     decoder_3_in = add([decoder_4, encoder_3])
# #     decoder_3_in = Activation('relu')(decoder_3_in)

#     decoder_3 = decoder_block(input_tensor=encoder_4, m=256, n=128)

#     decoder_2_in = add([decoder_3, encoder_2])
#     decoder_2_in = Activation('relu')(decoder_2_in)

    decoder_2 = decoder_block(input_tensor=encoder_2, m=128, n=64)

    decoder_1_in = add([decoder_2, encoder_1])
    decoder_1_in = Activation('relu')(decoder_1_in)

    decoder_1 = decoder_block(input_tensor=decoder_1_in, m=64, n=64)

    x = UpSampling2D((2, 2))(decoder_1)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(filters=32, kernel_size=(3, 3), padding="same")(x)

    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(filters=32, kernel_size=(3, 3), padding="same")(x)

    x = UpSampling2D((2, 2))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # x = Conv2D(filters=classes, kernel_size=(2, 2), padding="same")(x)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid') (x)
    model = Model(inputs=inputs, outputs=outputs)

    return model

# %%
train_x, test_x, train_y, test_y = train_test_split(train_5, thresh1, test_size=1/8.2, random_state=3017)

m = LinkNet()
m.compile(optimizer='adam', loss=bce_jaccard_loss, metrics=[iou_score, mean_iou, mse])
m.summary()

tensorboard = TensorBoard(log_dir='logs/{}'.format(time()))
earlystopper = EarlyStopping(patience=5, verbose=1)
checkpointer = ModelCheckpoint('model_segm_link.h5', verbose=1, save_best_only=True)

results = m.fit(train_x, train_y, validation_split=0.1, batch_size=64, epochs=100, 
                    callbacks=[earlystopper, checkpointer, tensorboard])
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_5 (InputLayer)            (None, 32, 32, 1)    0
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 1)    4           input_5[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 1)    0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 13, 13, 64)   3200        activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 7, 7, 64)     0           conv2d_77[0][0]
# ...

# %%
print('Метрики на тестовых данных', m.evaluate(test_x, test_y))

print(results.history.keys())
# вывод истории по метрике
plt.plot(results.history['mean_iou'])
plt.plot(results.history['val_mean_iou'])
plt.title('model_LinkNet mean_iou')
plt.ylabel('IoU')
plt.xlabel('epoch')
plt.legend(['mean_iou', 'val_mean_iou'], loc='upper left')
plt.show()

# вывод истории по коэффициенту Жаккара
plt.plot(results.history['iou_score'])
plt.plot(results.history['val_iou_score'])
plt.title('model_LinkNet iou_score')
plt.ylabel('iou_score')
plt.xlabel('epoch')
plt.legend(['iou_score', 'val_iou_score'], loc='upper left')
plt.show()

# вывод истории по средней квадратичной ошибке
plt.plot(results.history['mse'])
plt.plot(results.history['val_mse'])
plt.title('model_LinkNet mse')
plt.ylabel('mse')
plt.xlabel('epoch')
plt.legend(['mse', 'val_mse'], loc='upper left')
plt.show()

# вывод истории по потерям
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('model_LinkNet loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()
# Out:
# 399/399 [==============================] - 0s 1ms/step
# Метрики на тестовых данных [0.3602441954881625, 0.745601649272412, 0.7681701205726853, 0.03073573800592793]
# dict_keys(['val_loss', 'val_iou_score', 'val_mean_iou', 'val_mse', 'loss', 'iou_score', 'mean_iou', 'mse'])

# %%
# Предсказания на тренировочных, валидационных и тестовых данных
#model1 = load_model('model_segm.h5', custom_objects={'mean_iou': mean_iou, 'iou': iou})
preds_test = m.predict(test_x, verbose=1)

# # Определение порога прогноза
# preds_test_t = (preds_test > 1).astype(np.uint8)

# Проверка работоспособности на случайном обучающем примере
ix = random.randint(0, len(preds_test)-1)
print(ix)
py.imshow(np.squeeze(test_y[ix]))
plt.show()
py.imshow(np.squeeze(preds_test[ix]))
plt.show()
# Out:
# 399/399 [==============================] - 1s 2ms/step
# 359

# %% [markdown]
# Сравнение результатов сегментации сетями **U-net**(розовая кривая) и **LinkNet**(зеленая кривая)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Как видно из графиков сеть U-net обучилась быстрее сети Linknet. При этом метрика у этой сети явно выше (0.86 против 0.73).
#
# Таким образом  можно сделать 2 вывода:
# - о возможности применения подхода с использованием глубокого обучения для решения задач топологической оптимизации;
# - применение сети U-net более оправданно, за счёт большей скорости и более высокой метрики.

# %% [markdown]
# ### Элементы Transfer learning
#
# Transfer Learning (TL) — одно из направлений исследований в машинном обучении, которое изучает возможность применения знаний, полученных при решении одной задачи, к другой.
#
# Если внимательно изучить процесс глубокого обучения, то станет понятно следующее: на первых слоях сети пытаются уловить самые простые закономерности, на средних слоях — наиболее важные, и на последних слоях — специфические детали.
# ![image.png](attachment:image.png)
#
# Так как сформированный датасет относительно небольшой, можно экспортировать свойства из более ранних слоев уже обученных сетей и использовать их в качетве энкодера, состыковать их с декодером и получить модель, которая работает быстрее(т.к. часть слоёв уже обучены). Также существует мнение, что такие сети дают лучшие результаты, подтверждением тому является успешное использование сети TernausNet https://arxiv.org/abs/1801.05746, которая построена на основе U-net с энкодером на основе VGG11.
#
# Для сравнения моделей сегментации c предобученными слоями используем библиотеку segmentation-models.
#
# **Segmentation-models** - это библиотека Python с нейронными сетями для сегментации изображений на основе фреймворка Keras (Tensorflow).
#
# Основными функциями этой библиотеки являются:
# - API высокого уровня (всего две строки для создания NN)
# - 4 модели архитектуры для бинарной и мультиклассовой сегментации (включая легендарный Unet)
# - 25 доступных оснований для каждой архитектуры
# - все основания имеют предварительно обученные веса для быстрой и лучшей сходимости

# %%
#!pip install segmentation-models

# %%
from segmentation_models import Unet, Linknet, PSPNet, FPN
from segmentation_models.backbones import get_preprocessing
from segmentation_models.losses import bce_jaccard_loss
from segmentation_models.metrics import iou_score

# %% [markdown]
# Модель U-net с предобученным энкодером 'resnet34'

# %%
train_x, test_x, train_y, test_y = train_test_split(train_2_5, thresh1, test_size=1/8.2, random_state=3017)

model_unet = Unet(backbone_name='resnet34', input_shape=(32, 32, 3), encoder_weights='imagenet', freeze_encoder=True)
model_unet.compile('Adam', loss=bce_jaccard_loss, metrics=[mean_iou, iou_score, mse])

tensorboard = TensorBoard(log_dir='logs/{}'.format(time()))
earlystopper = EarlyStopping(patience=5, verbose=1)
checkpointer = ModelCheckpoint('model_unet.h5', verbose=1, save_best_only=True)

# обучение модели
results = model_unet.fit(
    x=train_x,
    y=train_y,
    batch_size=16,
    epochs=100,
    validation_split=0.1,
    callbacks=[earlystopper, checkpointer, tensorboard]
)
# Out:
# C:\Users\Shakhrai\Anaconda3\envs\mitjasha\lib\site-packages\segmentation_models\utils.py:27: UserWarning: `freeze_encoder` is deprecated and will be removed in future releases, use `encoder_freeze` instead.
#   'in future releases, use `{new_arg}` instead.'.format(old_arg=old_arg, new_arg=new_arg))
# Train on 2578 samples, validate on 287 samples
# Epoch 1/100
# 2578/2578 [==============================] - 24s 9ms/step - loss: 0.6742 - mean_iou: 0.4989 - iou_score: 0.5368 - mse: 0.0647 - val_loss: 0.4686 - val_mean_iou: 0.6338 - val_iou_score: 0.6713 - val_mse: 0.0395
#
# Epoch 00001: val_loss improved from inf to 0.46856, saving model to model_unet.h5
# Epoch 2/100
# 2578/2578 [==============================] - 17s 7ms/step - loss: 0.2937 - mean_iou: 0.6748 - iou_score: 0.7842 - mse: 0.0228 - val_loss: 0.2463 - val_mean_iou: 0.7057 - val_iou_score: 0.8174 - val_mse: 0.0188
#
# Epoch 00002: val_loss improved from 0.46856 to 0.24626, saving model to model_unet.h5
# Epoch 3/100
# ...

# %%
print('Метрики на тестовых данных', model_unet.evaluate(test_x, test_y))

print(results.history.keys())
# вывод истории по метрике
plt.plot(results.history['mean_iou'])
plt.plot(results.history['val_mean_iou'])
plt.title('model_unet mean_iou')
plt.ylabel('IoU')
plt.xlabel('epoch')
plt.legend(['mean_iou', 'val_mean_iou'], loc='upper left')
plt.show()

# вывод истории по коэффициенту Жаккара
plt.plot(results.history['iou_score'])
plt.plot(results.history['val_iou_score'])
plt.title('model_unet iou_score')
plt.ylabel('iou_score')
plt.xlabel('epoch')
plt.legend(['iou_score', 'val_iou_score'], loc='upper left')
plt.show()

# вывод истории по средней квадратичной ошибке
plt.plot(results.history['mse'])
plt.plot(results.history['val_mse'])
plt.title('model_unet mse')
plt.ylabel('mse')
plt.xlabel('epoch')
plt.legend(['mse', 'val_mse'], loc='upper left')
plt.show()

# вывод истории по потерям
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('model_unet loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()
# Out:
# 399/399 [==============================] - 1s 1ms/step
# Метрики на тестовых данных [0.12051714598236227, 0.8378930773053851, 0.9187890863358825, 0.010065107699717047]
# dict_keys(['val_loss', 'val_mean_iou', 'val_iou_score', 'val_mse', 'loss', 'mean_iou', 'iou_score', 'mse'])

# %%
# Предсказания на тренировочных, валидационных и тестовых данных
#model1 = load_model('model_segm.h5', custom_objects={'mean_iou': mean_iou, 'iou': iou})
preds_test = model_unet.predict(test_x, verbose=1)

# # Определение порога прогноза
# preds_test_t = (preds_test > 1).astype(np.uint8)

# Проверка работоспособности на случайном обучающем примере
ix = random.randint(0, len(preds_test)-1)
print(ix)
py.imshow(np.squeeze(test_y[ix]))
plt.show()
py.imshow(np.squeeze(preds_test[ix]))
plt.show()
# Out:
# 399/399 [==============================] - 1s 3ms/step
# 331

# %% [markdown]
# Модель Linknet с предобученным энкодером 'resnet34'

# %%
train_x, test_x, train_y, test_y = train_test_split(train_2_5, thresh1, test_size=1/8.2, random_state=3017)

model_linknet = Linknet(backbone_name='resnet34', input_shape=(32, 32, 3), encoder_weights='imagenet', freeze_encoder=True)
model_linknet.compile('Adam', loss=bce_jaccard_loss, metrics=[mean_iou, iou_score, mse])

tensorboard = TensorBoard(log_dir='logs/{}'.format(time()))
earlystopper = EarlyStopping(patience=5, verbose=1)
checkpointer = ModelCheckpoint('model_linknet.h5', verbose=1, save_best_only=True)

# обучение модели
results = model_linknet.fit(
    x=train_x,
    y=train_y,
    batch_size=16,
    epochs=100,
    validation_split=0.1,
    callbacks=[earlystopper, checkpointer, tensorboard]
)
# Out:
# Train on 2578 samples, validate on 287 samples
# Epoch 1/100
# 2578/2578 [==============================] - 25s 10ms/step - loss: 0.8664 - mean_iou: 0.4439 - iou_score: 0.3914 - mse: 0.0803 - val_loss: 0.7939 - val_mean_iou: 0.5593 - val_iou_score: 0.4399 - val_mse: 0.0652
#
# Epoch 00001: val_loss improved from inf to 0.79387, saving model to model_linknet.h5
# Epoch 2/100
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.4636 - mean_iou: 0.6049 - iou_score: 0.6711 - mse: 0.0389 - val_loss: 0.4855 - val_mean_iou: 0.6396 - val_iou_score: 0.6624 - val_mse: 0.0396
#
# Epoch 00002: val_loss improved from 0.79387 to 0.48554, saving model to model_linknet.h5
# Epoch 3/100
# 2578/2578 [==============================] - 18s 7ms/step - loss: 0.3727 - mean_iou: 0.6610 - iou_score: 0.7362 - mse: 0.0308 - val_loss: 0.4254 - val_mean_iou: 0.6787 - val_iou_score: 0.7121 - val_mse: 0.0360
#
# ...

# %%
print('Метрики на тестовых данных', model_linknet.evaluate(test_x, test_y))

print(results.history.keys())
# вывод истории по метрике
plt.plot(results.history['mean_iou'])
plt.plot(results.history['val_mean_iou'])
plt.title('model_Linknet mean_iou')
plt.ylabel('IoU')
plt.xlabel('epoch')
plt.legend(['mean_iou', 'val_mean_iou'], loc='upper left')
plt.show()

# вывод истории по коэффициенту Жаккара
plt.plot(results.history['iou_score'])
plt.plot(results.history['val_iou_score'])
plt.title('model_Linknet iou_score')
plt.ylabel('iou_score')
plt.xlabel('epoch')
plt.legend(['iou_score', 'val_iou_score'], loc='upper left')
plt.show()

# вывод истории по средней квадратичной ошибке
plt.plot(results.history['mse'])
plt.plot(results.history['val_mse'])
plt.title('model_Linknet mse')
plt.ylabel('mse')
plt.xlabel('epoch')
plt.legend(['mse', 'val_mse'], loc='upper left')
plt.show()

# вывод истории по потерям
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('model_Linknet loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss'], loc='upper left')
plt.show()
# Out:
# 399/399 [==============================] - 0s 1ms/step
# Метрики на тестовых данных [0.19025342383032157, 0.8068729816821584, 0.8713441966171551, 0.016018930066348913]
# dict_keys(['val_loss', 'val_mean_iou', 'val_iou_score', 'val_mse', 'loss', 'mean_iou', 'iou_score', 'mse'])

# %%
# Предсказания на тренировочных, валидационных и тестовых данных
#model1 = load_model('model_segm.h5', custom_objects={'mean_iou': mean_iou, 'iou': iou})
preds_test = model_linknet.predict(test_x, verbose=1)

# # Определение порога прогноза
# preds_test_t = (preds_test > 1).astype(np.uint8)

# Проверка работоспособности на случайном обучающем примере
ix = random.randint(0, len(preds_test)-1)
print(ix)
py.imshow(np.squeeze(test_x[ix]), cmap='Blues')
plt.show()
py.imshow(np.squeeze(test_y[ix]), cmap='Blues')
plt.show()
py.imshow(np.squeeze(preds_test[ix]), cmap='Blues')
plt.show()
# Out:
# 399/399 [==============================] - 0s 464us/step
# 31
